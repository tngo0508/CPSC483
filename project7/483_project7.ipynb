# %% [markdown]
# # THOMAS NGO
# # TEVIN VU

# %% [markdown]
# # 1. Use read_csv() to load and examine the dataset.

# %%
import pandas as pd
df = pd.read_csv('groceries.csv')
df
# Out:
#      apples  bananas  beer  bread  broccoli  diapers  eggs  milk  potatoes  \
# 0      6.00     1.50  0.00   0.00      4.00     0.00  2.00  3.00      0.00
# 1      3.50     1.00  3.50   2.00      2.00     0.00  0.00  0.00      7.00
# 2      1.50     0.50  3.00   0.50      1.25     0.00  0.75  2.00      0.75
# 3      1.67     0.67  0.00   0.33      0.33    20.67  1.33  5.33      0.67
# 4      5.00     1.00  5.00   1.00      2.00     0.00  0.00  0.00      3.00
# ..      ...      ...   ...    ...       ...      ...   ...   ...       ...
# 245    1.33     0.33  0.00   0.33      0.67    20.67  1.00  3.00      0.67
# 246    3.25     0.50  2.25   0.50      0.75     0.00  1.00  1.75      1.00
# 247    2.25     1.00  2.25   1.00      1.75     0.00  0.75  2.00      1.00
# 248    3.50     1.00  2.75   1.00      1.75     0.00  0.75  3.00      1.00
# 249    2.00     1.00  0.00   0.00      5.50     0.00  1.50  6.00      0.00
#
#      steak
# 0    17.50
# 1     0.00
# 2     6.50
# 3     2.33
# ...

# %% [markdown]
# # 2. Use sklearn.cluster.KMeans to cluster the dataset using the default parameters. Assign the labels_ attribute determined by the algorithm to a new column in your DataFrame. How many clusters are there?

# %%
from sklearn.cluster import KMeans
kmeans = KMeans().fit(df)
df['label'] = kmeans.labels_
df
# Out:
#      apples  bananas  beer  bread  broccoli  diapers  eggs  milk  potatoes  \
# 0      6.00     1.50  0.00   0.00      4.00     0.00  2.00  3.00      0.00
# 1      3.50     1.00  3.50   2.00      2.00     0.00  0.00  0.00      7.00
# 2      1.50     0.50  3.00   0.50      1.25     0.00  0.75  2.00      0.75
# 3      1.67     0.67  0.00   0.33      0.33    20.67  1.33  5.33      0.67
# 4      5.00     1.00  5.00   1.00      2.00     0.00  0.00  0.00      3.00
# ..      ...      ...   ...    ...       ...      ...   ...   ...       ...
# 245    1.33     0.33  0.00   0.33      0.67    20.67  1.00  3.00      0.67
# 246    3.25     0.50  2.25   0.50      0.75     0.00  1.00  1.75      1.00
# 247    2.25     1.00  2.25   1.00      1.75     0.00  0.75  2.00      1.00
# 248    3.50     1.00  2.75   1.00      1.75     0.00  0.75  3.00      1.00
# 249    2.00     1.00  0.00   0.00      5.50     0.00  1.50  6.00      0.00
#
#      steak  label
# 0    17.50      7
# 1     0.00      6
# ...

# %%
print(set(kmeans.labels_))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# ## How many clusters are there?
# There are 8 clusters

# %% [markdown]
# # 3.Use pandas.DataFrame.groupby() to group the data by cluster assignment, then use the GroupBy object to examine descriptive statistics such as minimum, maximum, and mean. Describe any differences you see between the clusters.

# %%
df.groupby(['label']).min()
# Out:
#        apples  bananas  beer  bread  broccoli  diapers  eggs  milk  potatoes  \
# label
# 0        2.00     1.00   3.0   1.00      4.50     0.00  0.00  0.00      2.50
# 1        0.67     0.33   0.0   0.33      0.33    20.33  0.67  2.67      0.00
# 2        2.00     1.00   0.0   0.00      3.50     0.00  1.50  3.00      0.00
# 3        0.40     0.40   1.2   0.20      0.00     4.00  0.20  0.60      1.00
# 4        1.00     0.50   1.5   0.50      0.75     0.00  0.75  1.50      0.75
# 5        0.67     0.33   0.0   0.33      0.33    13.67  0.67  3.00      0.00
# 6        2.00     1.00   3.0   1.00      1.50     0.00  0.00  0.00      2.50
# 7        2.00     1.00   0.0   0.00      3.50     0.00  1.50  3.00      0.00
#
#        steak
# label
# 0       0.00
# 1       1.67
# 2      10.00
# 3       0.00
# 4       2.50
# 5       1.67
# 6       0.00
# 7      15.50

# %%
df.groupby(['label']).max()
# Out:
#        apples  bananas  beer  bread  broccoli  diapers  eggs  milk  potatoes  \
# label
# 0         7.0     2.00   6.0   2.50      9.00     0.00  0.00  0.00      7.50
# 1         2.0     0.67   0.0   0.67      0.67    26.33  1.67  5.33      0.67
# 2         6.5     2.00   0.0   0.00      7.00     0.00  3.00  6.00      0.00
# 3         1.6     0.80   3.4   0.80      0.00     7.80  1.20  0.80      3.00
# 4         3.5     1.00   3.0   1.25      1.75     0.00  1.50  3.00      1.00
# 5         2.0     0.67   0.0   0.67      0.67    19.00  1.67  5.33      0.67
# 6         6.5     2.00   6.0   2.50      5.50     0.00  0.00  0.00      7.50
# 7         6.5     2.00   0.0   0.00      7.00     0.00  3.00  6.00      0.00
#
#        steak
# label
# 0       0.00
# 1       3.00
# 2      15.00
# 3       0.00
# 4       7.25
# 5       3.00
# 6       0.00
# 7      19.50

# %%
df.groupby(['label']).mean()
# Out:
#          apples   bananas      beer     bread  broccoli    diapers      eggs  \
# label
# 0      4.760000  1.420000  4.800000  1.700000  7.380000   0.000000  0.000000
# 1      1.445714  0.540476  0.000000  0.491905  0.491905  23.363810  1.096190
# 2      4.092593  1.537037  0.000000  0.000000  5.018519   0.000000  2.129630
# 3      0.951020  0.604082  2.224490  0.444898  0.000000   6.257143  0.640816
# 4      2.407407  0.717593  2.273148  0.907407  1.208333   0.000000  1.106481
# 5      1.417143  0.500000  0.000000  0.536429  0.572857  16.083214  1.131429
# 6      4.095238  1.547619  4.380952  1.928571  3.333333   0.000000  0.000000
# 7      4.100000  1.360000  0.000000  0.000000  5.380000   0.000000  2.300000
#
#            milk  potatoes      steak
# label
# 0      0.000000  4.500000   0.000000
# 1      3.826667  0.364762   2.396667
# 2      4.851852  0.000000  12.851852
# 3      0.710204  1.910204   0.000000
# 4      2.222222  0.884259   4.578704
# ...

# %% [markdown]
# ## Describe any differences you see between the clusters
# There is some clusters doesn't have any datas in them. There is some clusters have a lot of datas in them compare to other clusters

# %% [markdown]
# # 4.There’s no particular reason to think that the default value of K is the correct one for this dataset. Let’s switch to hierarchical clustering to see if we can visualize how the data clusters together.
# - Plot a scipy.cluster.hierarchy.dendrogram() for the dataset. Single linkage may not be the best choice for the dataset, but it is relatively quick to compute and will help us make a decision on the number of clusters.
# - Based on the dendrogram, how many clusters appear to be present in the dataset?

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
Z = hierarchy.linkage(df, 'single')
plt.figure(figsize=(25,10))
dn = hierarchy.dendrogram(Z)

# %% [markdown]
# After running many times, the pattern that we can see is that there are 5 clusters

# %% [markdown]
# # 5. Repeat experiment (2) using the number of clusters you determined to be present in experiment (4).

# %%
df_5 = pd.read_csv('groceries.csv')
kmeans_n_clusters = KMeans(n_clusters=5).fit(df_5)
df_5['label'] = kmeans_n_clusters.labels_
df_5
# Out:
#      apples  bananas  beer  bread  broccoli  diapers  eggs  milk  potatoes  \
# 0      6.00     1.50  0.00   0.00      4.00     0.00  2.00  3.00      0.00
# 1      3.50     1.00  3.50   2.00      2.00     0.00  0.00  0.00      7.00
# 2      1.50     0.50  3.00   0.50      1.25     0.00  0.75  2.00      0.75
# 3      1.67     0.67  0.00   0.33      0.33    20.67  1.33  5.33      0.67
# 4      5.00     1.00  5.00   1.00      2.00     0.00  0.00  0.00      3.00
# ..      ...      ...   ...    ...       ...      ...   ...   ...       ...
# 245    1.33     0.33  0.00   0.33      0.67    20.67  1.00  3.00      0.67
# 246    3.25     0.50  2.25   0.50      0.75     0.00  1.00  1.75      1.00
# 247    2.25     1.00  2.25   1.00      1.75     0.00  0.75  2.00      1.00
# 248    3.50     1.00  2.75   1.00      1.75     0.00  0.75  3.00      1.00
# 249    2.00     1.00  0.00   0.00      5.50     0.00  1.50  6.00      0.00
#
#      steak  label
# 0    17.50      2
# 1     0.00      4
# ...

# %% [markdown]
# ## How many clusters are there?

# %%
print(set(kmeans_n_clusters.labels_))
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# There are 5 clusters

# %%
Z_5 = hierarchy.linkage(df, 'single')
plt.figure(figsize=(25,10))
dn = hierarchy.dendrogram(Z_5)

# %% [markdown]
# After running many times, the pattern that we can see is that there are 5 clusters

# %% [markdown]
# ## 6. Now switch to sklearn.cluster.AgglomerativeClustering() and repeat for the same number of clusters. How do the label assignments compare for the two algorithms?
# Caution: don’t include the cluster number assigned by K-Means as one of the features to be clustered, or it will skew your results.

# %%
from sklearn.cluster import AgglomerativeClustering
df_6 = pd.read_csv('groceries.csv')
clustering = AgglomerativeClustering(n_clusters=5).fit(df_6)
df_6['label'] = clustering.labels_
df_6
# Out:
#      apples  bananas  beer  bread  broccoli  diapers  eggs  milk  potatoes  \
# 0      6.00     1.50  0.00   0.00      4.00     0.00  2.00  3.00      0.00
# 1      3.50     1.00  3.50   2.00      2.00     0.00  0.00  0.00      7.00
# 2      1.50     0.50  3.00   0.50      1.25     0.00  0.75  2.00      0.75
# 3      1.67     0.67  0.00   0.33      0.33    20.67  1.33  5.33      0.67
# 4      5.00     1.00  5.00   1.00      2.00     0.00  0.00  0.00      3.00
# ..      ...      ...   ...    ...       ...      ...   ...   ...       ...
# 245    1.33     0.33  0.00   0.33      0.67    20.67  1.00  3.00      0.67
# 246    3.25     0.50  2.25   0.50      0.75     0.00  1.00  1.75      1.00
# 247    2.25     1.00  2.25   1.00      1.75     0.00  0.75  2.00      1.00
# 248    3.50     1.00  2.75   1.00      1.75     0.00  0.75  3.00      1.00
# 249    2.00     1.00  0.00   0.00      5.50     0.00  1.50  6.00      0.00
#
#      steak  label
# 0    17.50      2
# 1     0.00      1
# ...

# %%
print(set(clustering.labels_))
# Out:
# {0, 1, 2, 3, 4}

# %%
from collections import Counter
print('Agglomerate clustering\n', Counter(clustering.labels_))
print('K-means\n', Counter(kmeans_n_clusters.labels_))
# Out:
# Agglomerate clustering
#  Counter({3: 54, 2: 52, 0: 49, 4: 49, 1: 46})
# K-means
#  Counter({1: 54, 2: 52, 0: 49, 3: 49, 4: 46})

# %% [markdown]
# ## How do the label assignments compare for the two algorithms?

# %% [markdown]
# Even though the labels are different for each cluster, the label assignments for two algorithms are the same. For example, the Aggolomerate clustering, as shown above, has 54 items of label 3. Likewise, K-means has 54 items of label 4. Although 3 is different 4, the number of items for each label are the same for two algorithms.

# %% [markdown]
# # 7. Repeat experiment (3) with the clusters you obtained in experiment (5). How would you describe the various types of customers? What can you determine about them based on the data? For each segment identified, list some other items they are and are not likely to buy in future shopping trips.

# %%
df_5.groupby(['label']).min()
# Out:
#        apples  bananas  beer  bread  broccoli  diapers  eggs  milk  potatoes  \
# label
# 0        0.67     0.33   0.0   0.33      0.33    13.67  0.67  2.67      0.00
# 1        1.00     0.50   1.5   0.50      0.75     0.00  0.75  1.50      0.75
# 2        2.00     1.00   0.0   0.00      3.50     0.00  1.50  3.00      0.00
# 3        0.40     0.40   1.2   0.20      0.00     4.00  0.20  0.60      1.00
# 4        2.00     1.00   3.0   1.00      1.50     0.00  0.00  0.00      2.50
#
#        steak
# label
# 0       1.67
# 1       2.50
# 2      10.00
# 3       0.00
# 4       0.00

# %%
df_5.groupby(['label']).max()
# Out:
#        apples  bananas  beer  bread  broccoli  diapers  eggs  milk  potatoes  \
# label
# 0         2.0     0.67   0.0   0.67      0.67    26.33  1.67  5.33      0.67
# 1         3.5     1.00   3.0   1.25      1.75     0.00  1.50  3.00      1.00
# 2         6.5     2.00   0.0   0.00      7.00     0.00  3.00  6.00      0.00
# 3         1.6     0.80   3.4   0.80      0.00     7.80  1.20  0.80      3.00
# 4         7.0     2.00   6.0   2.50      9.00     0.00  0.00  0.00      7.50
#
#        steak
# label
# 0       3.00
# 1       7.25
# 2      19.50
# 3       0.00
# 4       0.00

# %%
df_5.groupby(['label']).mean()
# Out:
#          apples   bananas      beer     bread  broccoli    diapers      eggs  \
# label
# 0      1.429388  0.517347  0.000000  0.517347  0.538163  19.203469  1.116327
# 1      2.407407  0.717593  2.273148  0.907407  1.208333   0.000000  1.106481
# 2      4.096154  1.451923  0.000000  0.000000  5.192308   0.000000  2.211538
# 3      0.951020  0.604082  2.224490  0.444898  0.000000   6.257143  0.640816
# 4      4.456522  1.478261  4.608696  1.804348  5.532609   0.000000  0.000000
#
#            milk  potatoes      steak
# label
# 0      4.027959  0.360204   2.408980
# 1      2.222222  0.884259   4.578704
# 2      4.605769  0.000000  15.144231
# 3      0.710204  1.910204   0.000000
# 4      0.000000  4.989130   0.000000

# %% [markdown]
# ## What can you determine about them based on the data?

# %% [markdown]
# The data shows that there are clusters representing for a group of vegan and a group of vegetarians. Besides, there are two groups having babies and one of them has more babies than the other. In addition, there is a low carbs or healthy group that doesn't drink beer, bread and potatoes.

# %% [markdown]
# ## For each segment identified, list some other items they are and are not likely to buy in future shopping trips.

# %% [markdown]
# - For vegans, they tend to buy apple, bananas, beer, bread, broccoli, and potatoes. They tend not to buy eggs, milk, and steak.
# - For vegetarians, they are not likely to buy steak.
# - For babies group, they are likely to buy diapers. One of them is not likely to buy steak. The other is not likely to buy beer.
# - For healthy group, they are likely to buy apple, bananas, eggs, milk, and steak. They are not likely to buy beer, bread, and potatoes.
